# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
face_cascade = cv2.CascadeClassifier('Classifiers/haar/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('Classifiers/haar/haarcascade_eye.xml')

# %%
img = cv2.imread("me.jpg")
b,g,r = cv2.split(img)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)
# plt.title('Matplotlib')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
arr = np.asarray(gray)
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[311 180 527 527]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,0),2)

# %%
b,g,r = cv2.split(img)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)

# %%
gray_face = gray[y:y+h, x:x+w] 
face = img[y:y+h, x:x+w]
eyes = eye_cascade.detectMultiScale(gray_face)

# %%
for (ex,ey,ew,eh) in eyes: 
    cv2.rectangle(face,(ex,ey),(ex+ew,ey+eh),(0,225,255),2)

# %%
b,g,r = cv2.split(face)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)

# %%
def detect_eyes(img, img_gray, classifier):
    coords = cascade.detectMultiScale(img_gray, 1.3, 5)# detect eyes
    height = np.size(image, 0) # get face frame height
    for (x, y, w, h) in coords:
        if y+h > height/2: # pass if the eye is at the bottom
            pass

# %%
b,g,r = cv2.split(img)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)

# %%
def detect_eyes(img, classifier):
    gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    eyes = cascade.detectMultiScale(gray_frame, 1.3, 5) # detect eyes
    width = np.size(image, 1) # get face frame width
    height = np.size(image, 0) # get face frame height
    left_eye = None
    right_eye = None
    for (x, y, w, h) in eyes:
        if y > height / 2:
            pass
        eyecenter = x + w / 2  # get the eye center
        if eyecenter < width * 0.5:
            left_eye = img[y:y + h, x:x + w]
        else:
            right_eye = img[y:y + h, x:x + w]
    return left_eye, right_eye

# %%
def detect_faces(img, classifier):
    gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    coords = cascade.detectMultiScale(gray_frame, 1.3, 5)
    if len(coords) > 1:
        biggest = (0, 0, 0, 0)
        for i in coords:
            if i[3] > biggest[3]:
                biggest = i
        biggest = np.array([i], np.int32)
    elif len(coords) == 1:
        biggest = coords
    else:
        return None
    for (x, y, w, h) in biggest:
        frame = img[y:y + h, x:x + w]
    return frame

# %%
detector_params = cv2.SimpleBlobDetector_Params()
detector_params.filterByArea = True
detector_params.maxArea = 1500
detector = cv2.SimpleBlobDetector_create(detector_params)

# %%
threshold = 128
_, img2 = cv2.threshold(img, threshold, 255, cv2.THRESH_BINARY)
b,g,r = cv2.split(img2)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)

# %%
def cut_eyebrows(img):
    height, width = img.shape[:2]
    eyebrow_h = int(height / 4)
    img = img[eyebrow_h:height, 0:width]  # cut eyebrows out (15 px)
    
    return img

# %% [markdown]
# # YAHA SE ACTUAL CODE HAI... ISKE UPAR PRACTICE THA

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
face_cascade = cv2.CascadeClassifier('Classifiers/haar/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('Classifiers/haar/haarcascade_eye.xml')
detector_params = cv2.SimpleBlobDetector_Params()
detector_params.filterByArea = True
detector_params.maxArea = 1500
detector = cv2.SimpleBlobDetector_create(detector_params)

# %%
def detect_faces(img, cascade):
    gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    coords = cascade.detectMultiScale(gray_frame, 1.3, 5)
    if len(coords) > 1:
        biggest = (0, 0, 0, 0)
        for i in coords:
            if i[3] > biggest[3]:
                biggest = i
        biggest = np.array([i], np.int32)
    elif len(coords) == 1:
        biggest = coords
    else:
        return None
    for (x, y, w, h) in biggest:
        print("detect_faces",x,y,w,h)
        frame = img[y:y + h, x:x + w]
    return frame

# %%
def detect_eyes(img, cascade):
    gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    eyes = cascade.detectMultiScale(gray_frame, 1.3, 5)  # detect eyes
    width = np.size(img, 1)  # get face frame width
    height = np.size(img, 0)  # get face frame height
    left_eye = None
    right_eye = None
    for (x, y, w, h) in eyes:
        print("detect_eyes",x,y,w,h)
        if y > height / 2:
            pass
        eyecenter = x + w / 2  # get the eye center
        if eyecenter < width * 0.5:
            left_eye = img[y:y + h, x:x + w]
        else:
            right_eye = img[y:y + h, x:x + w]
    return left_eye, right_eye

# %%
def cut_eyebrows(img):
    height, width = img.shape[:2]
    eyebrow_h = int(height / 4)
    img = img[eyebrow_h:height, 0:width]  # cut eyebrows out (15 px)

    return img

# %%
def blob_process(img, threshold, detector):
    gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, img = cv2.threshold(gray_frame, threshold, 255, cv2.THRESH_BINARY)
    img = cv2.erode(img, None, iterations=2)
    img = cv2.dilate(img, None, iterations=4)
    img = cv2.medianBlur(img, 5)
    keypoints = detector.detect(img)
    print(keypoints)
    return keypoints

# %%
def nothing(x):
    pass

# %%
img = cv2.imread("me.jpg")
b,g,r = cv2.split(img)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)

# %%
gray_picture = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
arr = np.asarray(gray_picture)
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
faces = face_cascade.detectMultiScale(gray_picture, 1.3, 5)

# %%
for (x,y,w,h) in faces:
    print(x,y,w,h)
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,0),2)
b,g,r = cv2.split(img)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)
# Out:
# 311 180 527 527

# %%
gray_face = gray_picture[y:y+h, x:x+w]
face = img[y:y+h, x:x+w]
eyes = eye_cascade.detectMultiScale(gray_face)
for (ex,ey,ew,eh) in eyes:
    print(ex,ey,ew,eh)
    cv2.rectangle(face,(ex,ey),(ex+ew,ey+eh),(0,225,255),2)
b,g,r = cv2.split(img)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)
# Out:
# 300 156 107 107
# 112 157 98 98

# %%
face_frame = detect_faces(img, face_cascade)
b,g,r = cv2.split(face_frame)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)
# Out:
# detect_faces 311 180 527 527

# %%
if face_frame is not None:
    eyes = detect_eyes(face_frame, eye_cascade)
    plt.subplot(1,2,1)
    b,g,r = cv2.split(eyes[0])
    frame_rgb = cv2.merge((r,g,b))
    plt.imshow(frame_rgb)
    plt.subplot(1,2,2)
    b,g,r = cv2.split(eyes[1])
    frame_rgb = cv2.merge((r,g,b))
    plt.imshow(frame_rgb)
# Out:
# detect_eyes 113 157 98 98
# detect_eyes 301 156 107 107

# %%
    i=1
    for eye in eyes:
        if eye is not None:
            threshold = r = cv2.getTrackbarPos('threshold', 'image')
            eye = cut_eyebrows(eye)
            plt.subplot(2,2,i)
            i += 2
            b,g,r = cv2.split(eye)
            frame_rgb = cv2.merge((r,g,b))
            plt.imshow(frame_rgb)
            keypoints = blob_process(eye, 128, detector)
            eye = cv2.drawKeypoints(eye, keypoints, eye, (0, 0, 255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
            plt.subplot(2,2,i-1)
            b,g,r = cv2.split(eye)
            frame_rgb = cv2.merge((r,g,b))
            plt.imshow(frame_rgb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-a7f4f8d9365e> in <module>
#       9         frame_rgb = cv2.merge((r,g,b))
#      10         plt.imshow(frame_rgb)
# ---> 11         keypoints = blob_process(eye, 128, detector)
#      12         eye = cv2.drawKeypoints(eye, keypoints, eye, (0, 0, 255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#      13         plt.subplot(2,2,i-1)
#
# TypeError: blob_process() takes 2 positional arguments but 3 were given

# %%
def blob_process(img, detector):
    gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, img = cv2.threshold(gray_frame, 40, 255, cv2.THRESH_BINARY)
    img = cv2.erode(img, None, iterations=4) #1
    img = cv2.dilate(img, None, iterations=3) #2
    img = cv2.medianBlur(img, 15)
    keypoints = detector.detect(img)
    plt.subplot(1,2,1)
    arr = np.asarray(img)
    plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
    faces = face_cascade.detectMultiScale(gray_picture, 1.3, 5)
    return keypoints
keypoints = blob_process(eyes[0], detector)
plt.subplot(1,2,2)
E_l = cv2.drawKeypoints(eyes[0], keypoints, eye[0], (0, 0, 255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
b,g,r = cv2.split(E_l)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)

# %%
def blob_process(img, detector):
    gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, img = cv2.threshold(gray_frame, 45, 255, cv2.THRESH_BINARY)
    img = cv2.erode(img, None, iterations=4) #1
    img = cv2.dilate(img, None, iterations=3) #2
    img = cv2.medianBlur(img, 15)
    keypoints = detector.detect(img)
    plt.subplot(1,2,1)
    arr = np.asarray(img)
    plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
    faces = face_cascade.detectMultiScale(gray_picture, 1.3, 5)
    return keypoints
keypoints = blob_process(eyes[1], detector)
plt.subplot(1,2,2)
E_r = cv2.drawKeypoints(eyes[1], keypoints, eye[1], (0, 0, 255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
b,g,r = cv2.split(E_r)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)

# %%
plt.subplot(1,3,1)
gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, img2 = cv2.threshold(gray_frame, 135, 255, cv2.THRESH_BINARY)
arr = np.asarray(img2)
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.title('Threshold = 135')
faces = face_cascade.detectMultiScale(gray_picture, 1.3, 5)
plt.subplot(1,3,2)
gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, img2 = cv2.threshold(gray_frame, 90, 255, cv2.THRESH_BINARY)
arr = np.asarray(img2)
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.title('Threshold = 90')
faces = face_cascade.detectMultiScale(gray_picture, 1.3, 5)
plt.subplot(1,3,3)
gray_frame = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, img2 = cv2.threshold(gray_frame, 45, 255, cv2.THRESH_BINARY)
arr = np.asarray(img2)
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.title('Threshold = 45')
faces = face_cascade.detectMultiScale(gray_picture, 1.3, 5)
